# %%
import spacy

# %%
nlp = spacy.blank("en")
doc = nlp("Dr. Strange loves thirupathi laddu as it costs free.")
for token in doc:
  print(token)
print(doc)
print(type(doc))
print(type(nlp))
# Out:
# Dr.
# Strange
# loves
# thirupathi
# laddu
# as
# it
# costs
# free
# .
# Dr. Strange loves thirupathi laddu as it costs free.
# <class 'spacy.tokens.doc.Doc'>
# <class 'spacy.lang.en.English'>
